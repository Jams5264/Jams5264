# %% [markdown]
# <a href="https://colab.research.google.com/github/Jams5264/Jams5264/blob/main/MachineLearningtidytest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# pandas = Python Data Analysis Library

# %%
df = pd.read_csv('/content/tidyadvertising_ETT - tidyadvertising_ETT (1).csv')
  #typically, df is used or data is used instead of dataframe

# %%
df.head()
  #1st five rows
# Out:
#       tv  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.tail()
#last five rows
# Out:
#          tv  radio  newspaper  sales
# 1195   38.2    3.7       13.8    7.6
# 1196   94.2    4.9        8.1    9.7
# 1197  177.0    9.3        6.4   12.8
# 1198  283.6   42.0       66.2   25.5
# 1199  232.1    8.6        8.7   13.4

# %%
df.info()
  # data types - [float = decimal,] [integer = number,] [object = text]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tv         1200 non-null   float64
#  1   radio      1200 non-null   float64
#  2   newspaper  1200 non-null   float64
#  3   sales      1200 non-null   float64
# dtypes: float64(4)
# memory usage: 37.6 KB

# %%
#check for null values
df.isnull().sum()
# Out:
# tv           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
#plot - really quick way to see relationships.
import seaborn as sns #seaborn is a python data  visualization library based on matplotlib
# %matplotlib inline
sns.pairplot(df)

# %%
# 'heatmap' plots rectangular data in a color-encoded matrix and 
# 'corr' finds the pairwise correlation of all columns in a dataframe
sns.heatmap(df.corr())
